# %%
from ibm import get_hackathon_circuit
from utils import submit_job

job = submit_job(get_hackathon_circuit())
# Out:
# <qiskit.providers.ibmq.job.ibmqjob.IBMQJob object at 0x10ce11510>

# %%
job
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-6a82bb7535e1> in <module>
# ----> 1 job.id
#
# AttributeError: 'IBMQJob' object has no attribute 'id'

# %%
from utils import get_job_result

job_id = '5da3a08e51516a0019aa31e1'

job_res = get_job_result(job_id)

# %%
from collections import OrderedDict
import operator

counts = job_res.get_counts()
sorted_counts = OrderedDict(sorted(counts.items(), key=operator.itemgetter(1))[::-1])

print([(k[::-1], c) for k, c in sorted_counts.items()][:15])
# Out:
# [('10111101000010', 241), ('10001101110010', 234), ('10001101101000', 233), ('10000111101000', 231), ('10001101111000', 225), ('01001110110001', 224), ('10111101101000', 218), ('01111110000001', 218), ('01001110110100', 217), ('10001100100000', 7), ('01001101100110', 6), ('10000011100001', 6), ('11110000101010', 6), ('00101110101001', 6), ('10100100000010', 6)]

# %%
from graph_examples import get_ibm_graph

graph = get_ibm_graph()
most_probable = list(sorted_counts.keys())
valid_total_solutions = 0
number_of_valid_states_found = 0
found_invalid = False

for color_bitstring in most_probable:
    color_bitstring_corrected = color_bitstring[::-1]
    colored = graph.get_colored(color_bitstring_corrected)
    if not colored.is_coloring_valid():
        found_invalid = True
        # print(f"Not valid coloring: {color_bitstring_corrected} with count of {sorted_counts[color_bitstring]}")
    else:
        valid_total_solutions += 1

    if not found_invalid:
        number_of_valid_states_found += 1

print(f"Total valid solutions: {valid_total_solutions}")
print(f"From which algorithm found: {number_of_valid_states_found}")
# Out:
# Total valid solutions: 9
# From which algorithm found: 9

# %%
# for k, c in list(sorted_counts.items())[:9]:
#     print(k[::-1])

for i in range(7):
    s = set()
    for k, c in list(sorted_counts.items())[:9]:
        s.add(k[::-1][i * 2: i * 2 + 2])
    print(s)
# Out:
# {'10', '01'}
# {'11', '00'}
# {'11', '01'}
# {'11', '10', '01'}
# {'00', '10', '11'}
# {'00', '10', '01'}
# {'00', '10', '01'}

# %%
from utils import generate_contest_submission_file
from ibm import get_hackathon_circuit
from utils import get_job_result

job_id = '5da3a08e51516a0019aa31e1'
job_res = get_job_result(job_id)
qc = get_hackathon_circuit()


generate_contest_submission_file(qc, job_res)
# Out:
# /Users/misha/.pyenv/versions/miniconda3-latest/envs/ibm_hack/lib/python3.7/site-packages/qiskit/providers/ibmq/ibmqfactory.py:181: UserWarning: Credentials are already in use. The existing account in the session will be replaced.
#   warnings.warn('Credentials are already in use. The existing '
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-4eac5af85f8e> in <module>
#       5 job_id = '5da3a08e51516a0019aa31e1'
#       6 job_res = get_job_result(job_id)
# ----> 7 qc = get_hackathon_circuit()
#       8
#       9
#
# ~/Projects/gate42/events/ibm2019/IBM-Quantum-Challenge-2019/konbini_distribution/ibm.py in get_hackathon_circuit()
#       9
#      10 def get_hackathon_circuit():
# ---> 11     graph = get_ibm_graph()
#      12     qc = run_coloring_grover(graph, 5)
#      13     return qc
#
# ~/Projects/gate42/events/ibm2019/IBM-Quantum-Challenge-2019/konbini_distribution/graph_examples.py in get_ibm_graph()
#      74         [(2, 0), (2, 5), (2, 6), (2, 'C')],  # 0, 5, 6, 2, 4
#      75         [(3, 5), (3, 6), (1, 4)],
# ---> 76         [(3, 0), (3, 1), (3, 2), (3, 4)],  # 0, 1, 2, 4, 5, 6
#      77     ])  # cost 35635
#      78
#
# ~/Projects/gate42/events/ibm2019/IBM-Quantum-Challenge-2019/konbini_distribution/graph.py in redefine_groups(self, groups)
#     136                             break
#     137                     else:
# --> 138                         raise ValueError()
#     139                 else:
#     140                     new_group.append((self.vertices[start], self.vertices[end]))
#
# ValueError:
